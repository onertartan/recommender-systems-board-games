# %% [markdown]
# <a href="https://colab.research.google.com/github/onertartan/recommender-systems-board-games/blob/main/explanatory_4_content_based_data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CONTENT BASED RECOMMENDATION

# %% [markdown]
# Original Dataset is taken from <a>https://www.kaggle.com/datasets/jvanelteren/boardgamegeek-reviews</a>

# %% [markdown]
# Download and unzip file **games_detailed_info.zip**

# %%
# File link: https://drive.google.com/file/d/1v9p1P7Sauw285MEEU9swpdtmQnLPJpqk/view?usp=drive_link
# !gdown 1v9p1P7Sauw285MEEU9swpdtmQnLPJpqk&confirm=t

# %% [markdown]
# Import packages

# %%
import numpy as np
import pandas as pd
from functools import partial
from tqdm.auto import tqdm
import matplotlib.pyplot as plt
from zipfile import ZipFile

# %%
with ZipFile("games_detailed_info.zip") as zipFile:
    zipFile.extractall()

# %% [markdown]
# ## 1- EXAMINE DATA
# Check df_details head

# %%
df_games_detailed= pd.read_csv("games_detailed_info.csv",index_col = 2,low_memory=False) # use game id as index
pd.set_option('display.max_columns', None)
df_games_detailed.head(2)
# Out:
#        Unnamed: 0       type  \
# id
# 30549           0  boardgame
# 822             1  boardgame
#
#                                                thumbnail  \
# id
# 30549  https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...
# 822    https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...
#
#                                                    image      primary  \
# id
# 30549  https://cf.geekdo-images.com/S3ybV1LAp-8SnHIXL...     Pandemic
# 822    https://cf.geekdo-images.com/okM0dq_bEXnbyQTOv...  Carcassonne
#
#                                                alternate  \
# id
# 30549  ['EPIZOotic', 'Pandemia', 'Pandemia 10 Anivers...
# 822    ['Carcassonne Jubilee Edition', 'Carcassonne: ...
#
#                                              description  yearpublished  \
# id
# 30549  In Pandemic, several virulent diseases have br...           2008
# 822    Carcassonne is a tile-placement game in which ...           2000
#
#        minplayers  maxplayers  \
# id
# 30549           2           4
# 822             2           5
#
#                                    suggested_num_players  \
# id
# 30549  [OrderedDict([('@numplayers', '1'), ('result',...
# 822    [OrderedDict([('@numplayers', '1'), ('result',...
#
#                                      suggested_playerage  \
# id
# 30549  [OrderedDict([('@value', '2'), ('@numvotes', '...
# 822    [OrderedDict([('@value', '2'), ('@numvotes', '...
#
#                            suggested_language_dependence  playingtime  \
# id
# 30549  [OrderedDict([('@level', '6'), ('@value', 'No ...           45
# 822    [OrderedDict([('@level', '81'), ('@value', 'No...           45
#
#        minplaytime  maxplaytime  minage  \
# id
# 30549           45           45       8
# 822             30           45       7
#
#                                        boardgamecategory  \
# id
# 30549                                        ['Medical']
# 822    ['City Building', 'Medieval', 'Territory Build...
#
#                                        boardgamemechanic  \
# id
# 30549  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 822    ['Area Majority / Influence', 'Map Addition', ...
#
#                                          boardgamefamily  \
# id
# 30549  ['Components: Map (Global Scale)', 'Components...
# 822    ['Cities: Carcassonne (France)', 'Components: ...
#
#                                       boardgameexpansion  \
# id
# 30549  ['Pandemic: Gen Con 2016 Promos – Z-Force Team...
# 822    ['20 Jahre Darmstadt Spielt', 'Apothecaries (f...
#
#                                  boardgameimplementation  \
# id
# 30549  ['Pandemic Legacy: Season 0', 'Pandemic Legacy...
# 822    ['The Ark of the Covenant', 'Carcassonne für 2...
#
#             boardgamedesigner  \
# id
# 30549        ['Matt Leacock']
# 822    ['Klaus-Jürgen Wrede']
#
#                                          boardgameartist  \
# id
# 30549  ['Josh Cappel', 'Christian Hanisch', 'Régis Mo...
# 822    ['Doris Matthäus', 'Anne Pätzke', 'Chris Quill...
#
#                                       boardgamepublisher  usersrated  average  \
# id
# 30549  ['Z-Man Games', 'Albi', 'Asmodee', 'Asmodee It...      109006  7.58896
# 822    ['Hans im Glück', '999 Games', 'Albi', 'Bard C...      108776  7.41837
#
#        bayesaverage Board Game Rank  Strategy Game Rank  Family Game Rank  \
# id
# 30549       7.48669             106               121.0              18.0
# 822         7.30857             191                 NaN              41.0
#
#         stddev  median   owned  trading  wanting  wishing  numcomments  \
# id
# 30549  1.32857       0  168364     2508      625     9344        17305
# 822    1.30532       0  161299     1716      582     7383        19263
#
#        numweights  averageweight               boardgameintegration  \
# id
# 30549        5597         2.4063                                NaN
# 822          7690         1.9057  ['Carcassonne: Wheel of Fortune']
#
#                                     boardgamecompilation  Party Game Rank  \
# id
# 30549                                                NaN              NaN
# 822    ['Carcassonne Big Box', 'Carcassonne Big Box 2...              NaN
#
#        Abstract Game Rank  Thematic Rank  War Game Rank  Customizable Rank  \
# id
# 30549                 NaN            NaN            NaN                NaN
# 822                   NaN            NaN            NaN                NaN
#
#       Children's Game Rank  RPG Item Rank  Accessory Rank  Video Game Rank  \
# id
# 30549                  NaN            NaN             NaN              NaN
# 822                    NaN            NaN             NaN              NaN
#
#        Amiga Rank  Commodore 64 Rank  Arcade Rank  Atari ST Rank
# id
# 30549         NaN                NaN          NaN            NaN
# 822           NaN                NaN          NaN            NaN

# %% [markdown]
# Let's check columns and the shape.

# %%
print(df_games_detailed.columns.tolist())
# Out:
# ['Unnamed: 0', 'type', 'thumbnail', 'image', 'primary', 'alternate', 'description', 'yearpublished', 'minplayers', 'maxplayers', 'suggested_num_players', 'suggested_playerage', 'suggested_language_dependence', 'playingtime', 'minplaytime', 'maxplaytime', 'minage', 'boardgamecategory', 'boardgamemechanic', 'boardgamefamily', 'boardgameexpansion', 'boardgameimplementation', 'boardgamedesigner', 'boardgameartist', 'boardgamepublisher', 'usersrated', 'average', 'bayesaverage', 'Board Game Rank', 'Strategy Game Rank', 'Family Game Rank', 'stddev', 'median', 'owned', 'trading', 'wanting', 'wishing', 'numcomments', 'numweights', 'averageweight', 'boardgameintegration', 'boardgamecompilation', 'Party Game Rank', 'Abstract Game Rank', 'Thematic Rank', 'War Game Rank', 'Customizable Rank', "Children's Game Rank", 'RPG Item Rank', 'Accessory Rank', 'Video Game Rank', 'Amiga Rank', 'Commodore 64 Rank', 'Arcade Rank', 'Atari ST Rank']

# %%
df_games_detailed.shape
# Out:
# (21631, 55)

# %% [markdown]
# Let's create a dictionary dataframe mapping ids to game names. We will use this df to access game names using game ids.

# %%
df_id2game = df_games_detailed[[ "primary"]].copy()
df_id2game.head(2)
# Out:
#            primary
# id
# 30549     Pandemic
# 822    Carcassonne

# %% [markdown]
# We select the columns **boardgamecategory**  **boardgamemechanic** and **boardgamefamily** as  content columns.<br>
# We will also need game ranks to sort the games with equal distances.

# %%
df_content= df_games_detailed[["Board Game Rank","boardgamecategory","boardgamemechanic","boardgamefamily"]].copy()
df_content.rename(columns={"Board Game Rank":"Board_Game_Rank"},inplace = True)
df_content.head(3)
# Out:
#       Board_Game_Rank                                  boardgamecategory  \
# id
# 30549             106                                        ['Medical']
# 822               191  ['City Building', 'Medieval', 'Territory Build...
# 13                429                        ['Economic', 'Negotiation']
#
#                                        boardgamemechanic  \
# id
# 30549  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 822    ['Area Majority / Influence', 'Map Addition', ...
# 13     ['Dice Rolling', 'Hexagon Grid', 'Income', 'Mo...
#
#                                          boardgamefamily
# id
# 30549  ['Components: Map (Global Scale)', 'Components...
# 822    ['Cities: Carcassonne (France)', 'Components: ...
# 13     ['Animals: Sheep', 'Components: Hexagonal Tile...

# %% [markdown]
# We consider that as  we go from boardgamecategory to boardgamemechanic and boardgamefamily columns, we delve into more details.<br>
# In other words boardgamecategory provides more broad groups.

# %% [markdown]
# Let's check missing values for each column.

# %%
df_content.isna().sum()
# Out:
# Board_Game_Rank         0
# boardgamecategory     283
# boardgamemechanic    1590
# boardgamefamily      3761
# dtype: int64

# %% [markdown]
# We can see that as missing values increase as some games provide less details on boardgamemechanic and boardgamefamily.<br>
# (missing values increase in this order: boardgamecategory->boardgamemechanic -> boardgamefamily  ).<br>

# %% [markdown]
# ## 2 DATA CLEANING

# %% [markdown]
# We consider the existence of boardgamecategory values as the minimum requirement to provide recommendation. <br>**Therefore we drop rows with missing values in boardgamecategory.**

# %%
df_content.dropna(subset=["boardgamecategory"],inplace=True)

# %% [markdown]
# We drop the rows with missing values in "boardgamecategory", because we consider these features as fundamental features. <br>
# Noew let's check missing values again.

# %%
df_content.isna().sum()
# Out:
# Board_Game_Rank         0
# boardgamecategory       0
# boardgamemechanic    1538
# boardgamefamily      3676
# dtype: int64

# %% [markdown]
# We will fill the missing values in columns **boardgamemechanic** and **boardgamefamily** with empty lists.<br>
# (These empty lists are going to be represented as zeros in one-hot encoding).<br>
# Briefly, we don't throw games with missing values in **boardgamemechanic** and **boardgamefamily** columns. Instead, we will rely on **boardgamecategory** for similarity calculation.

# %% [markdown]
# Check the new shape.

# %%
df_content.shape
# Out:
# (21348, 4)

# %% [markdown]
# We can fill na values in **boardgamemechanic** and **boardgamefamily** with empty lists and check missing values again.

# %%
df_content["boardgamemechanic"][df_content["boardgamemechanic"].isna()] = df_content["boardgamemechanic"][df_content["boardgamemechanic"].isna()].apply(lambda x:[""])
df_content["boardgamefamily"][df_content["boardgamefamily"].isna()] = df_content["boardgamefamily"][df_content["boardgamefamily"].isna()].apply(lambda x:[""])
df_content.isna().sum()
# Out:
# Board_Game_Rank      0
# boardgamecategory    0
# boardgamemechanic    0
# boardgamefamily      0
# dtype: int64

# %% [markdown]
# In Data Preprocessing we will fill missing values(one-hot encoded attribute columns).<br>
# Euclidian similarity can mislead to similarity between two games with all zeros.<br>
# Since we will use Jaccard similarity, two games with zero attributes will not be considered similar.

# %% [markdown]
# ## 3- DATA PREPROCESSING

# %% [markdown]
# ### 3.1 Extract categorical content columns
#
# We will extract categorical content columns which are embedded in lists in rows of boardgamecategory,	boardgamemechanic and	boardgamefamily.  <br>
# Then, in the next step we will represent them as one-hot columns.

# %%
df_content.head(2)
# Out:
#       Board_Game_Rank                                  boardgamecategory  \
# id
# 30549             106                                        ['Medical']
# 822               191  ['City Building', 'Medieval', 'Territory Build...
#
#                                        boardgamemechanic  \
# id
# 30549  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 822    ['Area Majority / Influence', 'Map Addition', ...
#
#                                          boardgamefamily
# id
# 30549  ['Components: Map (Global Scale)', 'Components...
# 822    ['Cities: Carcassonne (France)', 'Components: ...

# %% [markdown]
# Each column has categorical attributes given in list format but in str datatype. <br>
# We have to interpret these strings as list. We can do this using literal_eval.<br>
# For example, <code>literal_eval("[1,2,3]")</code> will yield a list <code> [1,2,3]</code> .<br>

# %%
from ast import literal_eval
df_content["boardgamecategory"]  = df_content["boardgamecategory"].apply(lambda x: literal_eval(str(x)))
df_content["boardgamemechanic"] = df_content["boardgamemechanic"].apply(lambda x: literal_eval(str(x)))
df_content["boardgamefamily"] = df_content["boardgamefamily"].apply(lambda x: literal_eval(str(x)))

# %% [markdown]
# Once we conterted each cell content to list type, we can extract unique values to be used as one-hot encoding columns.

# %% [markdown]
# #### 3.1.1 Get unique values of boardgamecategory as a list.

# %%
category_cols = sorted(set(sum(df_content["boardgamecategory"].tolist(),[])))
print(category_cols)
print("Number of categories:",len(category_cols))
# Out:
# ['Abstract Strategy', 'Action / Dexterity', 'Adventure', 'Age of Reason', 'American Civil War', 'American Indian Wars', 'American Revolutionary War', 'American West', 'Ancient', 'Animals', 'Arabian', 'Aviation / Flight', 'Bluffing', 'Book', 'Card Game', "Children's Game", 'City Building', 'Civil War', 'Civilization', 'Collectible Components', 'Comic Book / Strip', 'Deduction', 'Dice', 'Economic', 'Educational', 'Electronic', 'Environmental', 'Expansion for Base-game', 'Exploration', 'Fan Expansion', 'Fantasy', 'Farming', 'Fighting', 'Game System', 'Horror', 'Humor', 'Industry / Manufacturing', 'Korean War', 'Mafia', 'Math', 'Mature / Adult', 'Maze', 'Medical', 'Medieval', 'Memory', 'Miniatures', 'Modern Warfare', 'Movies / TV / Radio theme', 'Murder/Mystery', 'Music', 'Mythology', 'Napoleonic', 'Nautical', 'Negotiation', 'Novel-based', 'Number', 'Party Game', 'Pike and Shot', 'Pirates', 'Political', 'Post-Napoleonic', 'Prehistoric', 'Print & Play', 'Puzzle', 'Racing', 'Real-time', 'Religious', 'Renaissance', 'Science Fiction', 'Space Exploration', 'Spies/Secret Agents', 'Sports', 'Territory Building', 'Trains', 'Transportation', 'Travel', 'Trivia', 'Video Game Theme', 'Vietnam War', 'Wargame', 'Word Game', 'World War I', 'World War II', 'Zombies']
# Number of categories: 84

# %% [markdown]
# #### 3.1.2 Get unique values of boardgamemechanic as a list.

# %%
mechanic_cols = sorted(set(sum(df_content["boardgamemechanic"].tolist(),[])))
print(mechanic_cols)
# Out:
# ['', 'Acting', 'Action Drafting', 'Action Points', 'Action Queue', 'Action Retrieval', 'Action Timer', 'Action/Event', 'Advantage Token', 'Alliances', 'Area Majority / Influence', 'Area Movement', 'Area-Impulse', 'Auction/Bidding', 'Auction: Dexterity', 'Auction: Dutch', 'Auction: Dutch Priority', 'Auction: English', 'Auction: Fixed Placement', 'Auction: Once Around', 'Auction: Sealed Bid', 'Auction: Turn Order Until Pass', 'Automatic Resource Growth', 'Betting and Bluffing', 'Bias', 'Bingo', 'Bribery', 'Campaign / Battle Card Driven', 'Card Drafting', 'Card Play Conflict Resolution', 'Catch the Leader', 'Chaining', 'Chit-Pull System', 'Closed Economy Auction', 'Command Cards', 'Commodity Speculation', 'Communication Limits', 'Connections', 'Constrained Bidding', 'Contracts', 'Cooperative Game', 'Crayon Rail System', 'Critical Hits and Failures', 'Cube Tower', 'Deck Construction', 'Deck, Bag, and Pool Building', 'Deduction', 'Delayed Purchase', 'Dice Rolling', 'Die Icon Resolution', 'Different Dice Movement', 'Drafting', 'Elapsed Real Time Ending', 'Enclosure', 'End Game Bonuses', 'Events', 'Finale Ending', 'Flicking', 'Follow', 'Force Commitment', 'Grid Coverage', 'Grid Movement', 'Hand Management', 'Hexagon Grid', 'Hidden Movement', 'Hidden Roles', 'Hidden Victory Points', 'Highest-Lowest Scoring', 'Hot Potato', 'I Cut, You Choose', 'Impulse Movement', 'Income', 'Increase Value of Unchosen Resources', 'Induction', 'Interrupts', 'Investment', 'Kill Steal', 'King of the Hill', 'Ladder Climbing', 'Layering', 'Legacy Game', 'Line Drawing', 'Line of Sight', 'Loans', 'Lose a Turn', 'Mancala', 'Map Addition', 'Map Deformation', 'Map Reduction', 'Market', 'Matching', 'Measurement Movement', 'Melding and Splaying', 'Memory', 'Minimap Resolution', 'Modular Board', 'Move Through Deck', 'Movement Points', 'Movement Template', 'Moving Multiple Units', 'Multiple Maps', 'Multiple-Lot Auction', 'Narrative Choice / Paragraph', 'Negotiation', 'Network and Route Building', 'Once-Per-Game Abilities', 'Order Counters', 'Ownership', 'Paper-and-Pencil', 'Passed Action Token', 'Pattern Building', 'Pattern Movement', 'Pattern Recognition', 'Physical Removal', 'Pick-up and Deliver', 'Pieces as Map', 'Player Elimination', 'Player Judge', 'Point to Point Movement', 'Predictive Bid', "Prisoner's Dilemma", 'Programmed Movement', 'Push Your Luck', 'Race', 'Random Production', 'Ratio / Combat Results Table', 'Re-rolling and Locking', 'Real-Time', 'Relative Movement', 'Resource to Move', 'Rock-Paper-Scissors', 'Role Playing', 'Roles with Asymmetric Information', 'Roll / Spin and Move', 'Rondel', 'Scenario / Mission / Campaign Game', 'Score-and-Reset Game', 'Secret Unit Deployment', 'Selection Order Bid', 'Semi-Cooperative Game', 'Set Collection', 'Simulation', 'Simultaneous Action Selection', 'Singing', 'Single Loser Game', 'Slide/Push', 'Solo / Solitaire Game', 'Speed Matching', 'Square Grid', 'Stacking and Balancing', 'Stat Check Resolution', 'Static Capture', 'Stock Holding', 'Storytelling', 'Sudden Death Ending', 'Take That', 'Targeted Clues', 'Team-Based Game', 'Tech Trees / Tech Tracks', 'Three Dimensional Movement', 'Tile Placement', 'Time Track', 'Track Movement', 'Trading', 'Traitor Game', 'Trick-taking', 'Tug of War', 'Turn Order: Auction', 'Turn Order: Claim Action', 'Turn Order: Pass Order', 'Turn Order: Progressive', 'Turn Order: Random', 'Turn Order: Role Order', 'Turn Order: Stat-Based', 'Variable Phase Order', 'Variable Player Powers', 'Variable Set-up', 'Victory Points as a Resource', 'Voting', 'Worker Placement', 'Worker Placement with Dice Workers', 'Worker Placement, Different Worker Types', 'Zone of Control']

# %%
# Remove empty string
mechanic_cols = mechanic_cols[1:]
print("Number of unique boardgamemechanic values:",len(mechanic_cols))
# Out:
# Number of unique boardgamemechanic values: 182

# %% [markdown]
# #### 3.1.3 Get unique values of boardgamefamily as a list.
# Note that differently from the previous two steps, we have to exclude some values(attributes) in boardgamefamily which **we didn't include in family_cols(like "Admin", "Game", "Trivia")**.

# %%
family_cols = sorted( {x for row in df_content["boardgamefamily"]  for x in row
               if not (x.startswith("Admin") or x.startswith("Game") or x.startswith("Crowdfunding") or x.startswith("Digital Implementations")
                   or x.startswith("Digital Implementations")  or x.startswith("Trivia")  ) } )
print(family_cols)
# Out:
# ['', 'Ancient: Babylon', 'Ancient: Carthage', 'Ancient: Corinth', 'Ancient: Egypt', 'Ancient: Greece', 'Ancient: Indus Valley', 'Ancient: Jericho', 'Ancient: Magna Graecia', 'Ancient: Mesopotamia', 'Ancient: Pompeii', 'Ancient: Rome', 'Ancient: Sparta', 'Animals: Alligators / Crocodiles', 'Animals: Ants', 'Animals: Apes / Monkeys', 'Animals: Badgers', 'Animals: Bats', 'Animals: Bears', 'Animals: Beavers', 'Animals: Bees', 'Animals: Birds', 'Animals: Butterflies', 'Animals: Camels', 'Animals: Cats', 'Animals: Cattle / Cows', 'Animals: Chameleons', 'Animals: Chickens', 'Animals: Cockroaches', 'Animals: Coral / Jellyfish / Anemones', 'Animals: Coyotes', 'Animals: Crabs', 'Animals: Crows / Ravens / Magpies', 'Animals: Deer / Antelope', 'Animals: Dinosaurs', 'Animals: Dogs', 'Animals: Dolphins', 'Animals: Donkeys', 'Animals: Ducks', 'Animals: Eagles', 'Animals: Elephants', 'Animals: Emus', 'Animals: Fish / Fishes', 'Animals: Fleas', 'Animals: Flies', 'Animals: Foxes', 'Animals: Frogs / Toads', 'Animals: Geese', 'Animals: Giraffes', 'Animals: Goats', 'Animals: Gophers', 'Animals: Grasshoppers', 'Animals: Hamsters', 'Animals: Hedgehogs / Porcupines', 'Animals: Hippopotamuses', 'Animals: Horses', 'Animals: Insects', 'Animals: Kangaroos', 'Animals: Koalas', 'Animals: Ladybugs / Ladybirds', 'Animals: Lions', 'Animals: Lizards', 'Animals: Llamas', 'Animals: Mammoths', 'Animals: Marmots', 'Animals: Mice', 'Animals: Moles', 'Animals: Octopuses', 'Animals: Ostriches', 'Animals: Owls', 'Animals: Pandas', 'Animals: Penguins', 'Animals: Pigeons', 'Animals: Pigs', 'Animals: Rabbits', 'Animals: Raccoons', 'Animals: Rats', 'Animals: Rhinoceroses', 'Animals: Seals', 'Animals: Sharks', 'Animals: Sheep', 'Animals: Skunks', 'Animals: Sloths', 'Animals: Snails', 'Animals: Snakes', 'Animals: Spiders', 'Animals: Squirrels', 'Animals: Tigers', 'Animals: Turkeys', 'Animals: Turtles', 'Animals: Whales', 'Animals: Wolves', 'Animals: Wombats', 'Animals: Worms', 'Animals: Zebras', 'Authors: Agatha Christie', 'Authors: Alexandre Dumas', 'Authors: Astrid Lindgren', 'Authors: Beatrix Potter', 'Authors: Charles Dickens', 'Authors: Charles Perrault', 'Authors: Dr. Seuss', 'Authors: Edgar Rice Burroughs', 'Authors: Ellery Queen', 'Authors: Enid Blyton', 'Authors: Hans Christian Andersen', 'Authors: J.R.R. Tolkien', 'Authors: James Clavell', 'Authors: Jean de La Fontaine', 'Authors: Jules Verne', 'Authors: Karl May', 'Authors: Ken Follett', 'Authors: Michael Moorcock', 'Authors: Miguel de Cervantes', 'Authors: Mother Goose', 'Authors: Otfried Preußler', 'Authors: Richard Scarry', 'Authors: Roald Dahl', 'Authors: Stephen King', 'Authors: The Brothers Grimm', 'Authors: Victor Hugo', 'Authors: William Shakespeare', 'Books: A Song of Ice and Fire', 'Books: Alfons Åberg', 'Books: Alice in Wonderland', 'Books: Angelina Ballerina', 'Books: Babar', 'Books: Charlie and Lola', 'Books: Charlie and the Chocolate Factory', 'Books: Choose Your Own Adventure', 'Books: Curious George', 'Books: Der Dativ ist dem Genitiv sein Tod', 'Books: Der Kleine König', 'Books: Der kleine Eisbär', 'Books: Diary of a Wimpy Kid', 'Books: Discworld', 'Books: Dr. Jekyll and Mr. Hyde', 'Books: Dracula', 'Books: Dune', 'Books: Felix', 'Books: Goosebumps', 'Books: Guinness World Records', 'Books: Harry Potter', 'Books: Heidi', 'Books: His Dark Materials', 'Books: Hopalong Cassidy', 'Books: Inkworld', 'Books: James Bond', 'Books: Jim Button', 'Books: Jumanji / Zathura', 'Books: Le Petit Poucet', 'Books: Lilly the Witch', 'Books: Little Bear', 'Books: Little Raven Socks', 'Books: Madeline', 'Books: Maisy Mouse', 'Books: Mr. Men', 'Books: My Secret Unicorn', 'Books: Mystery Novels', 'Books: Paddington Bear', 'Books: Pippi Longstocking', 'Books: Sherlock Holmes', 'Books: Tark Mees Taskus', 'Books: The Berenstain Bears', 'Books: The Chronicles of Narnia', 'Books: The Gruffalo', 'Books: The Hunger Games', 'Books: The Kangaroo Chronicles', 'Books: The Little Prince', 'Books: The Princess Bride', 'Books: The T ...

# %%
# Remove the empty string
family_cols = family_cols[1:]
print("Number of unique boardgamefamily values:",len(family_cols))
# Out:
# Number of unique boardgamefamily values: 2643

# %% [markdown]
# ## 3.2 One-hot encode boardgamecategory, boardgamemechanics and boardgamefamily columns.
# We will create three one-hot encoded dataframes;
# * df_category
# * df_mechanic
# * df_family.<br>
# Then we will merge them.
# ### 3.2.1 Create **df_category** one-hot encoded dataframe
#
# In this step we spread  elements of the lists in boardgamecategory column to new one-hot categorical columns.<br>
# We initialize values in these columns as zeros.

# %%
def initialize_ohe(df_content, unpacked_column, ohe_columns):
    df_ohe = pd.concat([df_content[[unpacked_column]], pd.DataFrame(columns= ohe_columns)])
    df_ohe.fillna(0,inplace=True)
    df_ohe.iloc[:,1:] = df_ohe.iloc[:,1:].astype("int8")
    return df_ohe

# %%
df_category =  pd.DataFrame(0,index=df_content.index,columns= category_cols,dtype="int8")
df_category.head(2)
# Out:
#        Abstract Strategy  Action / Dexterity  Adventure  Age of Reason  \
# id
# 30549                  0                   0          0              0
# 822                    0                   0          0              0
#
#        American Civil War  American Indian Wars  American Revolutionary War  \
# id
# 30549                   0                     0                           0
# 822                     0                     0                           0
#
#        American West  Ancient  Animals  Arabian  Aviation / Flight  Bluffing  \
# id
# 30549              0        0        0        0                  0         0
# 822                0        0        0        0                  0         0
#
#        Book  Card Game  Children's Game  City Building  Civil War  \
# id
# 30549     0          0                0              0          0
# 822       0          0                0              0          0
#
#        Civilization  Collectible Components  Comic Book / Strip  Deduction  \
# id
# 30549             0                       0                   0          0
# 822               0                       0                   0          0
#
#        Dice  Economic  Educational  Electronic  Environmental  \
# id
# 30549     0         0            0           0              0
# 822       0         0            0           0              0
#
#        Expansion for Base-game  Exploration  Fan Expansion  Fantasy  Farming  \
# id
# 30549                        0            0              0        0        0
# 822                          0            0              0        0        0
#
#        Fighting  Game System  Horror  Humor  Industry / Manufacturing  \
# id
# 30549         0            0       0      0                         0
# 822           0            0       0      0                         0
#
#        Korean War  Mafia  Math  Mature / Adult  Maze  Medical  Medieval  \
# id
# 30549           0      0     0               0     0        0         0
# 822             0      0     0               0     0        0         0
#
#        Memory  Miniatures  Modern Warfare  Movies / TV / Radio theme  \
# id
# 30549       0           0               0                          0
# 822         0           0               0                          0
#
#        Murder/Mystery  Music  Mythology  Napoleonic  Nautical  Negotiation  \
# id
# 30549               0      0          0           0         0            0
# 822                 0      0          0           0         0            0
#
#        Novel-based  Number  Party Game  Pike and Shot  Pirates  Political  \
# id
# 30549            0       0           0              0        0          0
# 822              0       0           0              0        0          0
#
#        Post-Napoleonic  Prehistoric  Print & Play  Puzzle  Racing  Real-time  \
# id
# 30549                0            0             0       0       0          0
# 822                  0            0             0       0       0          0
#
#        Religious  Renaissance  Science Fiction  Space Exploration  \
# id
# 30549          0            0                0                  0
# 822            0            0                0                  0
#
#        Spies/Secret Agents  Sports  Territory Building  Trains  \
# id
# 30549                    0       0                   0       0
# 822                      0       0                   0       0
#
#        Transportation  Travel  Trivia  Video Game Theme  Vietnam War  Wargame  \
# id
# 30549               0       0       0                 0            0        0
# 822                 0       0       0                 0            0        0
#
#        Word Game  World War I  World War II  Zombies
# id
# 30549          0            0             0        0
# 822            0            0             0        0

# %% [markdown]
# For each game; at the categories that the game contains, replace cells initialized as 0s with 1s.

# %%
def complete_ohe(df_content,df_ohe, unpacked_column):
    for id in df_content.index:
        columns_for_ohe =  df_content.loc[id,unpacked_column]
        if columns_for_ohe != [""]:
            # we have excluded some columns like Admin,Game in df_family
            # therefore we have to ignore these columns
            columns_for_ohe= list(set(columns_for_ohe) & set(df_ohe.columns))
            df_ohe.loc[id, columns_for_ohe] = 1
    return df_ohe

# %%
df_category = complete_ohe(df_content, df_ohe=df_category, unpacked_column = "boardgamecategory")
df_category.head(2)
# Out:
#        Abstract Strategy  Action / Dexterity  Adventure  Age of Reason  \
# id
# 30549                  0                   0          0              0
# 822                    0                   0          0              0
#
#        American Civil War  American Indian Wars  American Revolutionary War  \
# id
# 30549                   0                     0                           0
# 822                     0                     0                           0
#
#        American West  Ancient  Animals  Arabian  Aviation / Flight  Bluffing  \
# id
# 30549              0        0        0        0                  0         0
# 822                0        0        0        0                  0         0
#
#        Book  Card Game  Children's Game  City Building  Civil War  \
# id
# 30549     0          0                0              0          0
# 822       0          0                0              1          0
#
#        Civilization  Collectible Components  Comic Book / Strip  Deduction  \
# id
# 30549             0                       0                   0          0
# 822               0                       0                   0          0
#
#        Dice  Economic  Educational  Electronic  Environmental  \
# id
# 30549     0         0            0           0              0
# 822       0         0            0           0              0
#
#        Expansion for Base-game  Exploration  Fan Expansion  Fantasy  Farming  \
# id
# 30549                        0            0              0        0        0
# 822                          0            0              0        0        0
#
#        Fighting  Game System  Horror  Humor  Industry / Manufacturing  \
# id
# 30549         0            0       0      0                         0
# 822           0            0       0      0                         0
#
#        Korean War  Mafia  Math  Mature / Adult  Maze  Medical  Medieval  \
# id
# 30549           0      0     0               0     0        1         0
# 822             0      0     0               0     0        0         1
#
#        Memory  Miniatures  Modern Warfare  Movies / TV / Radio theme  \
# id
# 30549       0           0               0                          0
# 822         0           0               0                          0
#
#        Murder/Mystery  Music  Mythology  Napoleonic  Nautical  Negotiation  \
# id
# 30549               0      0          0           0         0            0
# 822                 0      0          0           0         0            0
#
#        Novel-based  Number  Party Game  Pike and Shot  Pirates  Political  \
# id
# 30549            0       0           0              0        0          0
# 822              0       0           0              0        0          0
#
#        Post-Napoleonic  Prehistoric  Print & Play  Puzzle  Racing  Real-time  \
# id
# 30549                0            0             0       0       0          0
# 822                  0            0             0       0       0          0
#
#        Religious  Renaissance  Science Fiction  Space Exploration  \
# id
# 30549          0            0                0                  0
# 822            0            0                0                  0
#
#        Spies/Secret Agents  Sports  Territory Building  Trains  \
# id
# 30549                    0       0                   0       0
# 822                      0       0                   1       0
#
#        Transportation  Travel  Trivia  Video Game Theme  Vietnam War  Wargame  \
# id
# 30549               0       0       0                 0            0        0
# 822                 0       0       0                 0            0        0
#
#        Word Game  World War I  World War II  Zombies
# id
# 30549          0            0             0        0
# 822            0            0             0        0

# %%
print(df_category.columns.tolist())
# Out:
# ['Abstract Strategy', 'Action / Dexterity', 'Adventure', 'Age of Reason', 'American Civil War', 'American Indian Wars', 'American Revolutionary War', 'American West', 'Ancient', 'Animals', 'Arabian', 'Aviation / Flight', 'Bluffing', 'Book', 'Card Game', "Children's Game", 'City Building', 'Civil War', 'Civilization', 'Collectible Components', 'Comic Book / Strip', 'Deduction', 'Dice', 'Economic', 'Educational', 'Electronic', 'Environmental', 'Expansion for Base-game', 'Exploration', 'Fan Expansion', 'Fantasy', 'Farming', 'Fighting', 'Game System', 'Horror', 'Humor', 'Industry / Manufacturing', 'Korean War', 'Mafia', 'Math', 'Mature / Adult', 'Maze', 'Medical', 'Medieval', 'Memory', 'Miniatures', 'Modern Warfare', 'Movies / TV / Radio theme', 'Murder/Mystery', 'Music', 'Mythology', 'Napoleonic', 'Nautical', 'Negotiation', 'Novel-based', 'Number', 'Party Game', 'Pike and Shot', 'Pirates', 'Political', 'Post-Napoleonic', 'Prehistoric', 'Print & Play', 'Puzzle', 'Racing', 'Real-time', 'Religious', 'Renaissance', 'Science Fiction', 'Space Exploration', 'Spies/Secret Agents', 'Sports', 'Territory Building', 'Trains', 'Transportation', 'Travel', 'Trivia', 'Video Game Theme', 'Vietnam War', 'Wargame', 'Word Game', 'World War I', 'World War II', 'Zombies']

# %% [markdown]
# ### 3.2.2 Create **df_mechanic** one-hot encoded dataframe
# In this step we spread  elements of the lists in boardgamemechanic column to new one-hot categorical columns.<br>
# We initialize values in these columns as zeros.

# %%
df_mechanic =  pd.DataFrame(0,index=df_content.index,columns= mechanic_cols, dtype="int8")
df_mechanic.head(2)
# Out:
#        Acting  Action Drafting  Action Points  Action Queue  Action Retrieval  \
# id
# 30549       0                0              0             0                 0
# 822         0                0              0             0                 0
#
#        Action Timer  Action/Event  Advantage Token  Alliances  \
# id
# 30549             0             0                0          0
# 822               0             0                0          0
#
#        Area Majority / Influence  Area Movement  Area-Impulse  \
# id
# 30549                          0              0             0
# 822                            0              0             0
#
#        Auction/Bidding  Auction: Dexterity  Auction: Dutch  \
# id
# 30549                0                   0               0
# 822                  0                   0               0
#
#        Auction: Dutch Priority  Auction: English  Auction: Fixed Placement  \
# id
# 30549                        0                 0                         0
# 822                          0                 0                         0
#
#        Auction: Once Around  Auction: Sealed Bid  \
# id
# 30549                     0                    0
# 822                       0                    0
#
#        Auction: Turn Order Until Pass  Automatic Resource Growth  \
# id
# 30549                               0                          0
# 822                                 0                          0
#
#        Betting and Bluffing  Bias  Bingo  Bribery  \
# id
# 30549                     0     0      0        0
# 822                       0     0      0        0
#
#        Campaign / Battle Card Driven  Card Drafting  \
# id
# 30549                              0              0
# 822                                0              0
#
#        Card Play Conflict Resolution  Catch the Leader  Chaining  \
# id
# 30549                              0                 0         0
# 822                                0                 0         0
#
#        Chit-Pull System  Closed Economy Auction  Command Cards  \
# id
# 30549                 0                       0              0
# 822                   0                       0              0
#
#        Commodity Speculation  Communication Limits  Connections  \
# id
# 30549                      0                     0            0
# 822                        0                     0            0
#
#        Constrained Bidding  Contracts  Cooperative Game  Crayon Rail System  \
# id
# 30549                    0          0                 0                   0
# 822                      0          0                 0                   0
#
#        Critical Hits and Failures  Cube Tower  Deck Construction  \
# id
# 30549                           0           0                  0
# 822                             0           0                  0
#
#        Deck, Bag, and Pool Building  Deduction  Delayed Purchase  \
# id
# 30549                             0          0                 0
# 822                               0          0                 0
#
#        Dice Rolling  Die Icon Resolution  Different Dice Movement  Drafting  \
# id
# 30549             0                    0                        0         0
# 822               0                    0                        0         0
#
#        Elapsed Real Time Ending  Enclosure  End Game Bonuses  Events  \
# id
# 30549                         0          0                 0       0
# 822                           0          0                 0       0
#
#        Finale Ending  Flicking  Follow  Force Commitment  Grid Coverage  \
# id
# 30549              0         0       0                 0              0
# 822                0         0       0                 0              0
#
#        Grid Movement  Hand Management  Hexagon Grid  Hidden Movement  \
# id
# 30549              0                0             0                0
# 822                0                0             0                0
#
#        Hidden Roles  Hidden Victory Points  Highest-Lowest Scoring  \
# id
# 30549             0                      0                       0
# 822               0                      0                       0
#
#        Hot Potato  I Cut, You Choose  Impulse Movement  Income  \
# id
# 30549           0                  0                 0       0
# 822             0                  0                 0       0
#
#        Increase Value of Unchosen Resources  Induction  Interrupts  \
# id
# 30549                                     0          0           0
# 822                                       0          0           0
#
#        Investment  Kill Steal  King of the Hill  Ladder Climbing  Layering  \
# id
# 30549           0           0                 0                0         0
# 822             0           0                 0                0         0
#
#        Legacy Game  Line Drawing  Line of Sight  Loans  Lose a Turn  Mancala  \
# id
# 30549            0             0              0      0            0        0
# 822              0             0              0      0            0        0
#
#        Map Addition  Map Deformation  Map Reduction  Market  Matching  \
# id
# 30549             0                0              0       0         0
# 822               0                0              0       0         0
#
#        Measurement Movement  Melding and Splaying  Memory  Minimap Resolution  \
# id
# 30549                     0                     0       0                   0
# 822                       0                     0       0                   0
#
#        Modular Board  Move Through Deck  Movement Points  Movement Template  \
# id
# 30549              0                  0                0                  0
# 822                0                  0                0                  0
#
#        Moving Multiple Units  Multiple Maps  Multiple-Lot Auction  \
# id
# 30549                      0              0                     0
# 822                        0              0                     0
#
#        Narrative Choice / Paragraph  Negotiation  Network and Route Building  \
# id
# 30549                             0            0                           0
# 822                               0            0                           0
#
#        Once-Per-Game Abilities  Order Counters  Ownership  Paper-and-Pencil  \
# id
# 30549                        0               0          0                 0
# 822                          0               0          0                 0
#
#        Passed Action Token  Pattern Building  Pattern Movement  \
# id
# 30549                    0                 0                 0
# 822                      0                 0                 0
#
#        Pattern Recognition  Physical Removal  Pick-up and Deliver  \
# id
# 30549                    0                 0                    0
# 822                      0                 0                    0
#
#        Pieces as Map  Player Elimination  Player Judge  \
# id
# 30549              0                   0             0
# 822                0                   0             0
#
#        Point to Point Movement  Predictive Bid  Prisoner's Dilemma  \
# id
# 30549                        0               0                   0
# 822                          0               0                   0
#
#        Programmed Movement  Push Your Luck  Race  Random Production  \
# id
# 30549                    0               0     0                  0
# 822                      0               0     0                  0
#
#        Ratio / Combat Results Table  Re-rolling and Locking  Real-Time  \
# id
# 30549                             0                       0          0
# 822                               0                       0          0
#
#        Relative Movement  Resource to Move  Rock-Paper-Scissors  Role Playing  \
# id
# 30549                  0                 0                    0             0
# 822                    0                 0                    0             0
#
#        Roles with Asymmetric Information  Roll / Spin and Move  Rondel  \
# id
# 30549                                  0                     0       0
# 822                                    0                     0       0
#
#        Scenario / Mission / Campaign Game  Score-and-Reset Game  \
# id
# 30549                                   0                     0
# 822                                     0                     0
#
#        Secret Unit Deployment  Selection Order Bid  Semi-Cooperative Game  \
# id
# 30549                       0                    0                      0
# 822                         0                    0                      0
#
#        Set Collection  Simulation  Simultaneous Action Selection  Singing  \
# id
# 30549               0           0                              0        0
# 822                 0           0                              0        0
#
#        Single Loser Game  Slide/Push  Solo / Solitaire Game  Speed Matching  \
# id
# 30549                  0           0                      0               0
# 822                    0           0                      0               0
#
#        Square Grid  Stacking and Balancing  Stat Check Resolution  \
# id
# 30549            0                       0                      0
# 822              0                       0                      0
#
#        Static Capture  Stock Holding  Storytelling  Sudden Death Ending  \
# id
# 30549               0              0             0                    0
# 822                 0              0             0                    0
#
#        Take That  Targeted Clues  Team-Based Game  Tech Trees / Tech Tracks  \
# id
# 30549          0               0                0                         0
# 822            0               0                0                         0
#
#        Three Dimensional Movement  Tile Placement  Time Track  Track Movement  \
# id
# 30549                           0               0           0               0
# 822                             0               0           0               0
#
#        Trading  Traitor Game  Trick-taking  Tug of War  Turn Order: Auction  \
# id
# 30549        0             0             0           0                    0
# 822          0             0             0           0                    0
#
#        Turn Order: Claim Action  Turn Order: Pass Order  \
# id
# 30549                         0                       0
# 822                           0                       0
#
#        Turn Order: Progressive  Turn Order: Random  Turn Order: Role Order  \
# id
# 30549                        0                   0                       0
# 822                          0                   0                       0
#
#        Turn Order: Stat-Based  Variable Phase Order  Variable Player Powers  \
# id
# 30549                       0                     0                       0
# 822                         0                     0                       0
#
#        Variable Set-up  Victory Points as a Resource  Voting  \
# id
# 30549                0                             0       0
# 822                  0                             0       0
#
#        Worker Placement  Worker Placement with Dice Workers  \
# id
# 30549                 0                                   0
# 822                   0                                   0
#
#        Worker Placement, Different Worker Types  Zone of Control
# id
# 30549                                         0                0
# 822                                           0                0

# %% [markdown]
# For each game; at the categories that the game contains, replace cells initialized as 0s with 1s.

# %%
df_mechanic = complete_ohe(df_content, df_ohe= df_mechanic, unpacked_column = "boardgamemechanic")
df_mechanic.head(2)
# Out:
#        Acting  Action Drafting  Action Points  Action Queue  Action Retrieval  \
# id
# 30549       0                0              1             0                 0
# 822         0                0              0             0                 0
#
#        Action Timer  Action/Event  Advantage Token  Alliances  \
# id
# 30549             0             0                0          0
# 822               0             0                0          0
#
#        Area Majority / Influence  Area Movement  Area-Impulse  \
# id
# 30549                          0              0             0
# 822                            1              0             0
#
#        Auction/Bidding  Auction: Dexterity  Auction: Dutch  \
# id
# 30549                0                   0               0
# 822                  0                   0               0
#
#        Auction: Dutch Priority  Auction: English  Auction: Fixed Placement  \
# id
# 30549                        0                 0                         0
# 822                          0                 0                         0
#
#        Auction: Once Around  Auction: Sealed Bid  \
# id
# 30549                     0                    0
# 822                       0                    0
#
#        Auction: Turn Order Until Pass  Automatic Resource Growth  \
# id
# 30549                               0                          0
# 822                                 0                          0
#
#        Betting and Bluffing  Bias  Bingo  Bribery  \
# id
# 30549                     0     0      0        0
# 822                       0     0      0        0
#
#        Campaign / Battle Card Driven  Card Drafting  \
# id
# 30549                              0              0
# 822                                0              0
#
#        Card Play Conflict Resolution  Catch the Leader  Chaining  \
# id
# 30549                              0                 0         0
# 822                                0                 0         0
#
#        Chit-Pull System  Closed Economy Auction  Command Cards  \
# id
# 30549                 0                       0              0
# 822                   0                       0              0
#
#        Commodity Speculation  Communication Limits  Connections  \
# id
# 30549                      0                     0            0
# 822                        0                     0            0
#
#        Constrained Bidding  Contracts  Cooperative Game  Crayon Rail System  \
# id
# 30549                    0          0                 1                   0
# 822                      0          0                 0                   0
#
#        Critical Hits and Failures  Cube Tower  Deck Construction  \
# id
# 30549                           0           0                  0
# 822                             0           0                  0
#
#        Deck, Bag, and Pool Building  Deduction  Delayed Purchase  \
# id
# 30549                             0          0                 0
# 822                               0          0                 0
#
#        Dice Rolling  Die Icon Resolution  Different Dice Movement  Drafting  \
# id
# 30549             0                    0                        0         0
# 822               0                    0                        0         0
#
#        Elapsed Real Time Ending  Enclosure  End Game Bonuses  Events  \
# id
# 30549                         0          0                 0       0
# 822                           0          0                 0       0
#
#        Finale Ending  Flicking  Follow  Force Commitment  Grid Coverage  \
# id
# 30549              0         0       0                 0              0
# 822                0         0       0                 0              0
#
#        Grid Movement  Hand Management  Hexagon Grid  Hidden Movement  \
# id
# 30549              0                1             0                0
# 822                0                0             0                0
#
#        Hidden Roles  Hidden Victory Points  Highest-Lowest Scoring  \
# id
# 30549             0                      0                       0
# 822               0                      0                       0
#
#        Hot Potato  I Cut, You Choose  Impulse Movement  Income  \
# id
# 30549           0                  0                 0       0
# 822             0                  0                 0       0
#
#        Increase Value of Unchosen Resources  Induction  Interrupts  \
# id
# 30549                                     0          0           0
# 822                                       0          0           0
#
#        Investment  Kill Steal  King of the Hill  Ladder Climbing  Layering  \
# id
# 30549           0           0                 0                0         0
# 822             0           0                 0                0         0
#
#        Legacy Game  Line Drawing  Line of Sight  Loans  Lose a Turn  Mancala  \
# id
# 30549            0             0              0      0            0        0
# 822              0             0              0      0            0        0
#
#        Map Addition  Map Deformation  Map Reduction  Market  Matching  \
# id
# 30549             0                0              0       0         0
# 822               1                0              0       0         0
#
#        Measurement Movement  Melding and Splaying  Memory  Minimap Resolution  \
# id
# 30549                     0                     0       0                   0
# 822                       0                     0       0                   0
#
#        Modular Board  Move Through Deck  Movement Points  Movement Template  \
# id
# 30549              0                  0                0                  0
# 822                0                  0                0                  0
#
#        Moving Multiple Units  Multiple Maps  Multiple-Lot Auction  \
# id
# 30549                      0              0                     0
# 822                        0              0                     0
#
#        Narrative Choice / Paragraph  Negotiation  Network and Route Building  \
# id
# 30549                             0            0                           0
# 822                               0            0                           0
#
#        Once-Per-Game Abilities  Order Counters  Ownership  Paper-and-Pencil  \
# id
# 30549                        0               0          0                 0
# 822                          0               0          0                 0
#
#        Passed Action Token  Pattern Building  Pattern Movement  \
# id
# 30549                    0                 0                 0
# 822                      0                 0                 0
#
#        Pattern Recognition  Physical Removal  Pick-up and Deliver  \
# id
# 30549                    0                 0                    0
# 822                      0                 0                    0
#
#        Pieces as Map  Player Elimination  Player Judge  \
# id
# 30549              0                   0             0
# 822                0                   0             0
#
#        Point to Point Movement  Predictive Bid  Prisoner's Dilemma  \
# id
# 30549                        1               0                   0
# 822                          0               0                   0
#
#        Programmed Movement  Push Your Luck  Race  Random Production  \
# id
# 30549                    0               0     0                  0
# 822                      0               0     0                  0
#
#        Ratio / Combat Results Table  Re-rolling and Locking  Real-Time  \
# id
# 30549                             0                       0          0
# 822                               0                       0          0
#
#        Relative Movement  Resource to Move  Rock-Paper-Scissors  Role Playing  \
# id
# 30549                  0                 0                    0             0
# 822                    0                 0                    0             0
#
#        Roles with Asymmetric Information  Roll / Spin and Move  Rondel  \
# id
# 30549                                  0                     0       0
# 822                                    0                     0       0
#
#        Scenario / Mission / Campaign Game  Score-and-Reset Game  \
# id
# 30549                                   0                     0
# 822                                     0                     0
#
#        Secret Unit Deployment  Selection Order Bid  Semi-Cooperative Game  \
# id
# 30549                       0                    0                      0
# 822                         0                    0                      0
#
#        Set Collection  Simulation  Simultaneous Action Selection  Singing  \
# id
# 30549               1           0                              0        0
# 822                 0           0                              0        0
#
#        Single Loser Game  Slide/Push  Solo / Solitaire Game  Speed Matching  \
# id
# 30549                  0           0                      0               0
# 822                    0           0                      0               0
#
#        Square Grid  Stacking and Balancing  Stat Check Resolution  \
# id
# 30549            0                       0                      0
# 822              0                       0                      0
#
#        Static Capture  Stock Holding  Storytelling  Sudden Death Ending  \
# id
# 30549               0              0             0                    0
# 822                 0              0             0                    0
#
#        Take That  Targeted Clues  Team-Based Game  Tech Trees / Tech Tracks  \
# id
# 30549          0               0                0                         0
# 822            0               0                0                         0
#
#        Three Dimensional Movement  Tile Placement  Time Track  Track Movement  \
# id
# 30549                           0               0           0               0
# 822                             0               1           0               0
#
#        Trading  Traitor Game  Trick-taking  Tug of War  Turn Order: Auction  \
# id
# 30549        1             0             0           0                    0
# 822          0             0             0           0                    0
#
#        Turn Order: Claim Action  Turn Order: Pass Order  \
# id
# 30549                         0                       0
# 822                           0                       0
#
#        Turn Order: Progressive  Turn Order: Random  Turn Order: Role Order  \
# id
# 30549                        0                   0                       0
# 822                          0                   0                       0
#
#        Turn Order: Stat-Based  Variable Phase Order  Variable Player Powers  \
# id
# 30549                       0                     0                       1
# 822                         0                     0                       0
#
#        Variable Set-up  Victory Points as a Resource  Voting  \
# id
# 30549                0                             0       0
# 822                  0                             0       0
#
#        Worker Placement  Worker Placement with Dice Workers  \
# id
# 30549                 0                                   0
# 822                   0                                   0
#
#        Worker Placement, Different Worker Types  Zone of Control
# id
# 30549                                         0                0
# 822                                           0                0

# %% [markdown]
# ### 3.2.3 Create **df_family** one-hot encoded dataframe
# In this step we spread  elements of the lists in boardgamefamily column to new one-hot categorical columns.<br>
# We initialize values in these columns as zeros.

# %%
df_family =  pd.DataFrame(0,index=df_content.index,columns= family_cols, dtype="int8")
df_family.head(2)
# Out:
#        Ancient: Babylon  Ancient: Carthage  Ancient: Corinth  Ancient: Egypt  \
# id
# 30549                 0                  0                 0               0
# 822                   0                  0                 0               0
#
#        Ancient: Greece  Ancient: Indus Valley  Ancient: Jericho  \
# id
# 30549                0                      0                 0
# 822                  0                      0                 0
#
#        Ancient: Magna Graecia  Ancient: Mesopotamia  Ancient: Pompeii  \
# id
# 30549                       0                     0                 0
# 822                         0                     0                 0
#
#        Ancient: Rome  Ancient: Sparta  Animals: Alligators / Crocodiles  \
# id
# 30549              0                0                                 0
# 822                0                0                                 0
#
#        Animals: Ants  Animals: Apes / Monkeys  Animals: Badgers  \
# id
# 30549              0                        0                 0
# 822                0                        0                 0
#
#        Animals: Bats  Animals: Bears  Animals: Beavers  Animals: Bees  \
# id
# 30549              0               0                 0              0
# 822                0               0                 0              0
#
#        Animals: Birds  Animals: Butterflies  Animals: Camels  Animals: Cats  \
# id
# 30549               0                     0                0              0
# 822                 0                     0                0              0
#
#        Animals: Cattle / Cows  Animals: Chameleons  Animals: Chickens  \
# id
# 30549                       0                    0                  0
# 822                         0                    0                  0
#
#        Animals: Cockroaches  Animals: Coral / Jellyfish / Anemones  \
# id
# 30549                     0                                      0
# 822                       0                                      0
#
#        Animals: Coyotes  Animals: Crabs  Animals: Crows / Ravens / Magpies  \
# id
# 30549                 0               0                                  0
# 822                   0               0                                  0
#
#        Animals: Deer / Antelope  Animals: Dinosaurs  Animals: Dogs  \
# id
# 30549                         0                   0              0
# 822                           0                   0              0
#
#        Animals: Dolphins  Animals: Donkeys  Animals: Ducks  Animals: Eagles  \
# id
# 30549                  0                 0               0                0
# 822                    0                 0               0                0
#
#        Animals: Elephants  Animals: Emus  Animals: Fish / Fishes  \
# id
# 30549                   0              0                       0
# 822                     0              0                       0
#
#        Animals: Fleas  Animals: Flies  Animals: Foxes  Animals: Frogs / Toads  \
# id
# 30549               0               0               0                       0
# 822                 0               0               0                       0
#
#        Animals: Geese  Animals: Giraffes  Animals: Goats  Animals: Gophers  \
# id
# 30549               0                  0               0                 0
# 822                 0                  0               0                 0
#
#        Animals: Grasshoppers  Animals: Hamsters  \
# id
# 30549                      0                  0
# 822                        0                  0
#
#        Animals: Hedgehogs / Porcupines  Animals: Hippopotamuses  \
# id
# 30549                                0                        0
# 822                                  0                        0
#
#        Animals: Horses  Animals: Insects  Animals: Kangaroos  Animals: Koalas  \
# id
# 30549                0                 0                   0                0
# 822                  0                 0                   0                0
#
#        Animals: Ladybugs / Ladybirds  Animals: Lions  Animals: Lizards  \
# id
# 30549                              0               0                 0
# 822                                0               0                 0
#
#        Animals: Llamas  Animals: Mammoths  Animals: Marmots  Animals: Mice  \
# id
# 30549                0                  0                 0              0
# 822                  0                  0                 0              0
#
#        Animals: Moles  Animals: Octopuses  Animals: Ostriches  Animals: Owls  \
# id
# 30549               0                   0                   0              0
# 822                 0                   0                   0              0
#
#        Animals: Pandas  Animals: Penguins  Animals: Pigeons  Animals: Pigs  \
# id
# 30549                0                  0                 0              0
# 822                  0                  0                 0              0
#
#        Animals: Rabbits  Animals: Raccoons  Animals: Rats  \
# id
# 30549                 0                  0              0
# 822                   0                  0              0
#
#        Animals: Rhinoceroses  Animals: Seals  Animals: Sharks  Animals: Sheep  \
# id
# 30549                      0               0                0               0
# 822                        0               0                0               0
#
#        Animals: Skunks  Animals: Sloths  Animals: Snails  Animals: Snakes  \
# id
# 30549                0                0                0                0
# 822                  0                0                0                0
#
#        Animals: Spiders  Animals: Squirrels  Animals: Tigers  \
# id
# 30549                 0                   0                0
# 822                   0                   0                0
#
#        Animals: Turkeys  Animals: Turtles  Animals: Whales  Animals: Wolves  \
# id
# 30549                 0                 0                0                0
# 822                   0                 0                0                0
#
#        Animals: Wombats  Animals: Worms  Animals: Zebras  \
# id
# 30549                 0               0                0
# 822                   0               0                0
#
#        Authors: Agatha Christie  Authors: Alexandre Dumas  \
# id
# 30549                         0                         0
# 822                           0                         0
#
#        Authors: Astrid Lindgren  Authors: Beatrix Potter  \
# id
# 30549                         0                        0
# 822                           0                        0
#
#        Authors: Charles Dickens  Authors: Charles Perrault  \
# id
# 30549                         0                          0
# 822                           0                          0
#
#        Authors: Dr. Seuss  Authors: Edgar Rice Burroughs  \
# id
# 30549                   0                              0
# 822                     0                              0
#
#        Authors: Ellery Queen  Authors: Enid Blyton  \
# id
# 30549                      0                     0
# 822                        0                     0
#
#        Authors: Hans Christian Andersen  Authors: J.R.R. Tolkien  \
# id
# 30549                                 0                        0
# 822                                   0                        0
#
#        Authors: James Clavell  Authors: Jean de La Fontaine  \
# id
# 30549                       0                             0
# 822                         0                             0
#
#        Authors: Jules Verne  Authors: Karl May  Authors: Ken Follett  \
# id
# 30549                     0                  0                     0
# 822                       0                  0                     0
#
#        Authors: Michael Moorcock  Authors: Miguel de Cervantes  \
# id
# 30549                          0                             0
# 822                            0                             0
#
#        Authors: Mother Goose  Authors: Otfried Preußler  \
# id
# 30549                      0                          0
# 822                        0                          0
#
#        Authors: Richard Scarry  Authors: Roald Dahl  Authors: Stephen King  \
# id
# 30549                        0                    0                      0
# 822                          0                    0                      0
#
#        Authors: The Brothers Grimm  Authors: Victor Hugo  \
# id
# 30549                            0                     0
# 822                              0                     0
#
#        Authors: William Shakespeare  Books: A Song of Ice and Fire  \
# id
# 30549                             0                              0
# 822                               0                              0
#
#        Books: Alfons Åberg  Books: Alice in Wonderland  \
# id
# 30549                    0                           0
# 822                      0                           0
#
#        Books: Angelina Ballerina  Books: Babar  Books: Charlie and Lola  \
# id
# 30549                          0             0                        0
# 822                            0             0                        0
#
#        Books: Charlie and the Chocolate Factory  \
# id
# 30549                                         0
# 822                                           0
#
#        Books: Choose Your Own Adventure  Books: Curious George  \
# id
# 30549                                 0                      0
# 822                                   0                      0
#
#        Books: Der Dativ ist dem Genitiv sein Tod  Books: Der Kleine König  \
# id
# 30549                                          0                        0
# 822                                            0                        0
#
#        Books: Der kleine Eisbär  Books: Diary of a Wimpy Kid  \
# id
# 30549                         0                            0
# 822                           0                            0
#
#        Books: Discworld  Books: Dr. Jekyll and Mr. Hyde  Books: Dracula  \
# id
# 30549                 0                               0               0
# 822                   0                               0               0
#
#        Books: Dune  Books: Felix  Books: Goosebumps  \
# id
# 30549            0             0                  0
# 822              0             0                  0
#
#        Books: Guinness World Records  Books: Harry Potter  Books: Heidi  \
# id
# 30549                              0                    0             0
# 822                                0                    0             0
#
#        Books: His Dark Materials  Books: Hopalong Cassidy  Books: Inkworld  \
# id
# 30549                          0                        0                0
# 822                            0                        0                0
#
#        Books: James Bond  Books: Jim Button  Books: Jumanji / Zathura  \
# id
# 30549                  0                  0                         0
# 822                    0                  0                         0
#
#        Books: Le Petit Poucet  Books: Lilly the Witch  Books: Little Bear  \
# id
# 30549                       0                       0                   0
# 822                         0                       0                   0
#
#        Books: Little Raven Socks  Books: Madeline  Books: Maisy Mouse  \
# id
# 30549                          0                0                   0
# 822                            0                0                   0
#
#        Books: Mr. Men  Books: My Secret Unicorn  Books: Mystery Novels  \
# id
# 30549               0                         0                      0
# 822                 0                         0                      0
#
#        Books: Paddington Bear  Books: Pippi Longstocking  \
# id
# 30549                       0                          0
# 822                         0                          0
#
#        Books: Sherlock Holmes  Books: Tark Mees Taskus  \
# id
# 30549                       0                        0
# 822                         0                        0
#
#        Books: The Berenstain Bears  Books: The Chronicles of Narnia  \
# id
# 30549                            0                                0
# 822                              0                                0
#
#        Books: The Gruffalo  Books: The Hunger Games  \
# id
# 30549                    0                        0
# 822                      0                        0
#
#        Books: The Kangaroo Chronicles  Books: The Little Prince  \
# id
# 30549                               0                         0
# 822                                 0                         0
#
#        Books: The Princess Bride  Books: The Three Investigators  \
# id
# 30549                          0                               0
# 822                            0                               0
#
#        Books: The Witcher  Books: The Wizard of Oz  Books: Twilight  \
# id
# 30549                   0                        0                0
# 822                     0                        0                0
#
#        Books: Winnie the Pooh  Brands: Airlines  \
# id
# 30549                       0                 0
# 822                         0                 0
#
#        Brands: Automotive Products (Gasoline, Tires, etc.)  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Brands: Campbell's  Brands: Coca-Cola  Brands: Disney  \
# id
# 30549                   0                  0               0
# 822                     0                  0               0
#
#        Brands: Groceries  Brands: Harley-Davidson  Brands: John Deere  \
# id
# 30549                  0                        0                   0
# 822                    0                        0                   0
#
#        Brands: McDonald's  Brands: Restaurants  \
# id
# 30549                   0                    0
# 822                     0                    0
#
#        Brands: Television (TV) Networks  \
# id
# 30549                                 0
# 822                                   0
#
#        Brands: Vehicles (Cars, Trucks, etc.)  Card Games: Adding  \
# id
# 30549                                      0                   0
# 822                                        0                   0
#
#        Card Games: Beating  Card Games: Climbing  \
# id
# 30549                    0                     0
# 822                      0                     0
#
#        Card Games: Draw and Discard  Card Games: Exchange  \
# id
# 30549                             0                     0
# 822                               0                     0
#
#        Card Games: Fishing  Card Games: Matching  Card Games: Outplay  \
# id
# 30549                    0                     0                    0
# 822                      0                     0                    0
#
#        Card Games: Shedding / Stops  Cartaventura (BLAM!)  \
# id
# 30549                             0                     0
# 822                               0                     0
#
#        Category: Combinatorial  Category: Drinking Games  \
# id
# 30549                        0                         0
# 822                          0                         0
#
#        Category: Dungeon Crawler  Category: Escape Room Games  \
# id
# 30549                          0                            0
# 822                            0                            0
#
#        Category: Fighting Top Games  Category: MOBA  Category: Pick Them Up  \
# id
# 30549                             0               0                       0
# 822                               0               0                       0
#
#        Category: Print on Demand  Category: Sandbox  Category: Tower Defense  \
# id
# 30549                          0                  0                        0
# 822                            0                  0                        0
#
#        Category: Two players fighting games  Category: n in a row  \
# id
# 30549                                     0                     0
# 822                                       0                     0
#
#        Celebrities: Alfred Hitchcock  Celebrities: Bob Ross  \
# id
# 30549                              0                      0
# 822                                0                      0
#
#        Celebrities: Don Adams  Celebrities: Elvis Presley  \
# id
# 30549                       0                           0
# 822                         0                           0
#
#        Celebrities: Gerry Anderson  Celebrities: Lucille Ball  \
# id
# 30549                            0                          0
# 822                              0                          0
#
#        Celebrities: Monty Python  Celebrities: The Beatles  \
# id
# 30549                          0                         0
# 822                            0                         0
#
#        Celebrities: The Wiggles  Characters:  The Addams Family  \
# id
# 30549                         0                               0
# 822                           0                               0
#
#        Characters: 101 Dalmatians  Characters: Bamse  \
# id
# 30549                           0                  0
# 822                             0                  0
#
#        Characters: Benjamin the Elephant  Characters: Bozo the Clown  \
# id
# 30549                                  0                           0
# 822                                    0                           0
#
#        Characters: Buck Rogers  Characters: Caillou  \
# id
# 30549                        0                    0
# 822                          0                    0
#
#        Characters: Capt'n Sharky  Characters: Conan the Barbarian  \
# id
# 30549                          0                                0
# 822                            0                                0
#
#        Characters: Dragon Ball  Characters: Frankenstein  \
# id
# 30549                        0                         0
# 822                          0                         0
#
#        Characters: Funny Bunny  Characters: Hello Kitty  Characters: Hercules  \
# id
# 30549                        0                        0                     0
# 822                          0                        0                     0
#
#        Characters: Kikker & Vriendjes  Characters: Käpt'n Blaubär  \
# id
# 30549                               0                           0
# 822                                 0                           0
#
#        Characters: Lassie  Characters: Lauras Stern  Characters: Max & Moritz  \
# id
# 30549                   0                         0                         0
# 822                     0                         0                         0
#
#        Characters: Mickey Mouse  Characters: Miffy  Characters: Mister X  \
# id
# 30549                         0                  0                     0
# 822                           0                  0                     0
#
#        Characters: Moomins  Characters: Perry Rhodan  \
# id
# 30549                    0                         0
# 822                      0                         0
#
#        Characters: Pettersson und Findus  Characters: Schweine Schwarte  \
# id
# 30549                                  0                              0
# 822                                    0                              0
#
#        Characters: Smurfs  Characters: Sooty  Characters: Spirou et Fantasio  \
# id
# 30549                   0                  0                               0
# 822                     0                  0                               0
#
#        Characters: Tarzan  Characters: The Lone Ranger  \
# id
# 30549                   0                            0
# 822                     0                            0
#
#        Characters: The Three Stooges  Characters: Zorro  \
# id
# 30549                              0                  0
# 822                                0                  0
#
#        Cities: Aachen (Westphalia, Germany)  Cities: Abbeville (France)  \
# id
# 30549                                     0                           0
# 822                                       0                           0
#
#        Cities: Agra (India)  Cities: Albuera (Spain)  \
# id
# 30549                     0                        0
# 822                       0                        0
#
#        Cities: Alexandria (Egypt)  Cities: Amsterdam (The Netherlands)  \
# id
# 30549                           0                                    0
# 822                             0                                    0
#
#        Cities: Antwerp (Belgium)  Cities: Anzio (Italy)  \
# id
# 30549                          0                      0
# 822                            0                      0
#
#        Cities: Arcachon (France)  Cities: Arnhem (The Netherlands)  \
# id
# 30549                          0                                 0
# 822                            0                                 0
#
#        Cities: Arras (France)  Cities: Athens (Greece)  \
# id
# 30549                       0                        0
# 822                         0                        0
#
#        Cities: Atlanta (Georgia, USA)  \
# id
# 30549                               0
# 822                                 0
#
#        Cities: Atlantic City (New Jersey, USA)  Cities: Auerstedt (Germany)  \
# id
# 30549                                        0                            0
# 822                                          0                            0
#
#        Cities: Augsburg (Bavaria, Germany)  \
# id
# 30549                                    0
# 822                                      0
#
#        Cities: Austerlitz (Czech Republic)  Cities: Avignon (France)  \
# id
# 30549                                    0                         0
# 822                                      0                         0
#
#        Cities: Baghdad (Iraq)  Cities: Bagrationovsk (Russia)  \
# id
# 30549                       0                               0
# 822                         0                               0
#
#        Cities: Bailén (Spain)  Cities: Baltimore (Maryland, USA)  \
# id
# 30549                       0                                  0
# 822                         0                                  0
#
#        Cities: Bamberg (Bavaria, Germany)  Cities: Bangkok (Thailand)  \
# id
# 30549                                   0                           0
# 822                                     0                           0
#
#        Cities: Bannockburn (Scotland)  Cities: Barcelona (Spain)  \
# id
# 30549                               0                          0
# 822                                 0                          0
#
#        Cities: Bastogne (Belgium)  Cities: Beijing (China)  \
# id
# 30549                           0                        0
# 822                             0                        0
#
#        Cities: Bergamo (Italy)  Cities: Berlin (Germany)  \
# id
# 30549                        0                         0
# 822                          0                         0
#
#        Cities: Bern (Switzerland)  Cities: Bilbao (Spain)  \
# id
# 30549                           0                       0
# 822                             0                       0
#
#        Cities: Birmingham (England)  Cities: Bologna (Emilia-Romagna, Italy)  \
# id
# 30549                             0                                        0
# 822                               0                                        0
#
#        Cities: Bonn (Westphalia, Germany)  Cities: Bordeaux (France)  \
# id
# 30549                                   0                          0
# 822                                     0                          0
#
#        Cities: Borodino (Russia)  Cities: Boston (Massachusetts, USA)  \
# id
# 30549                          0                                    0
# 822                            0                                    0
#
#        Cities: Bourges (France)  Cities: Bremerhaven (Germany)  \
# id
# 30549                         0                              0
# 822                           0                              0
#
#        Cities: Brest (Brittany, France)  Cities: Brisbane (Australia)  \
# id
# 30549                                 0                             0
# 822                                   0                             0
#
#        Cities: Bristol (England)  Cities: Bruges (Belgium)  \
# id
# 30549                          0                         0
# 822                            0                         0
#
#        Cities: Brussels (Belgium)  Cities: Budapest (Hungary)  \
# id
# 30549                           0                           0
# 822                             0                           0
#
#        Cities: Buenos Aires (Argentina)  Cities: Buffalo (New York, USA)  \
# id
# 30549                                 0                                0
# 822                                   0                                0
#
#        Cities: Caen (France)  Cities: Cairo (Egypt)  Cities: Cambrai (France)  \
# id
# 30549                      0                      0                         0
# 822                        0                      0                         0
#
#        Cities: Canberra (Australia)  Cities: Cannes (France)  \
# id
# 30549                             0                        0
# 822                               0                        0
#
#        Cities: Canterbury (England)  Cities: Carcassonne (France)  \
# id
# 30549                             0                             0
# 822                               0                             0
#
#        Cities: Carentan (France)  Cities: Carson City (Nevada, USA)  \
# id
# 30549                          0                                  0
# 822                            0                                  0
#
#        Cities: Cartagena (Colombia)  Cities: Casablanca (Morocco)  \
# id
# 30549                             0                             0
# 822                               0                             0
#
#        Cities: Changde (China)  Cities: Cherbourg-en-Cotentin (France)  \
# id
# 30549                        0                                       0
# 822                          0                                       0
#
#        Cities: Chicago (Illinois, USA)  Cities: Châlons-en-Champagne (France)  \
# id
# 30549                                0                                      0
# 822                                  0                                      0
#
#        Cities: Cincinnati (Ohio, USA)  Cities: Cleveland (Ohio, USA)  \
# id
# 30549                               0                              0
# 822                                 0                              0
#
#        Cities: Colditz (Saxony, Germany)  Cities: Cologne (Germany)  \
# id
# 30549                                  0                          0
# 822                                    0                          0
#
#        Cities: Copenhagen (Denmark)  Cities: Corunna (Spain)  \
# id
# 30549                             0                        0
# 822                               0                        0
#
#        Cities: Cracow (Poland)  Cities: Cusco (Peru)  \
# id
# 30549                        0                     0
# 822                          0                     0
#
#        Cities: Córdoba (Andalusia, Spain)  Cities: Dallas (Texas, USA)  \
# id
# 30549                                   0                            0
# 822                                     0                            0
#
#        Cities: Damascus (Syria)  Cities: Debrecen (Hungary)  \
# id
# 30549                         0                           0
# 822                           0                           0
#
#        Cities: Detroit (Michigan, USA)  Cities: Deutsch-Wagram (Austria)  \
# id
# 30549                                0                                 0
# 822                                  0                                 0
#
#        Cities: Dieppe (France)  Cities: Dinant (Belgium)  \
# id
# 30549                        0                         0
# 822                          0                         0
#
#        Cities: Dodge City (Kansas, USA)  \
# id
# 30549                                 0
# 822                                   0
#
#        Cities: Dortmund (North Rhine-Westphalia, Germany)  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Cities: Dresden (Saxony, Germany)  Cities: Dublin (Ireland)  \
# id
# 30549                                  0                         0
# 822                                    0                         0
#
#        Cities: Dunkirk (France)  \
# id
# 30549                         0
# 822                           0
#
#        Cities: Eindhoven (North Brabant, Netherlands)  \
# id
# 30549                                               0
# 822                                                 0
#
#        Cities: Essen (Germany)  Cities: Estoril (Portugal)  \
# id
# 30549                        0                           0
# 822                          0                           0
#
#        Cities: Falaise (France)  Cities: Fallujah (Iraq)  \
# id
# 30549                         0                        0
# 822                           0                        0
#
#        Cities: Fleurus (Belgium)  Cities: Florence (Tuscany, Italy)  \
# id
# 30549                          0                                  0
# 822                            0                                  0
#
#        Cities: Frankfurt – Main (Germany)  Cities: Friedland (Prussia)  \
# id
# 30549                                   0                            0
# 822                                     0                            0
#
#        Cities: Fulda (Hesse, Germany)  Cities: Gdańsk (Poland)  \
# id
# 30549                               0                        0
# 822                                 0                        0
#
#        Cities: Genoa (Liguria, Italy)  Cities: Giza (Egypt)  \
# id
# 30549                               0                     0
# 822                                 0                     0
#
#        Cities: Glasgow (Scotland)  Cities: Granada (Andalusia, Spain)  \
# id
# 30549                           0                                   0
# 822                             0                                   0
#
#        Cities: Grenoble (France)  Cities: Grozny (Chechnya)  \
# id
# 30549                          0                          0
# 822                            0                          0
#
#        Cities: Guadalajara (Spain)  Cities: Győr (Hungary)  \
# id
# 30549                            0                       0
# 822                              0                       0
#
#        Cities: Hamburg (Germany)  Cities: Hameln (Saxony, Germany)  \
# id
# 30549                          0                                 0
# 822                            0                                 0
#
#        Cities: Hannut (Belgium)  Cities: Hanoi (Vietnam)  \
# id
# 30549                         0                        0
# 822                           0                        0
#
#        Cities: Hanover (Lower Saxony, Germany)  Cities: Hastings (England)  \
# id
# 30549                                        0                           0
# 822                                          0                           0
#
#        Cities: Havana (Cuba)  Cities: Helsinki (Finland)  \
# id
# 30549                      0                           0
# 822                        0                           0
#
#        Cities: Huế (Vietnam)  Cities: Incheon (South Korea)  \
# id
# 30549                      0                              0
# 822                        0                              0
#
#        Cities: Isfahan (Iran)  Cities: Istanbul (Turkey)  \
# id
# 30549                       0                          0
# 822                         0                          0
#
#        Cities: Jakarta (Indonesia)  Cities: Jena (Thuringia, Germany)  \
# id
# 30549                            0                                  0
# 822                              0                                  0
#
#        Cities: Jerusalem (Israel)  Cities: Kaliningrad (Russia)  \
# id
# 30549                           0                             0
# 822                             0                             0
#
#        Cities: Kansas City (Missouri, USA)  Cities: Kharkov (Ukraine)  \
# id
# 30549                                    0                          0
# 822                                      0                          0
#
#        Cities: Khartoum (Sudan)  Cities: Kiev (Ukraine)  \
# id
# 30549                         0                       0
# 822                           0                       0
#
#        Cities: Korsun (Ukraine)  Cities: Kursk (Russia)  \
# id
# 30549                         0                       0
# 822                           0                       0
#
#        Cities: Kyoto (Japan)  Cities: Königgrätz (Czech Republic)  \
# id
# 30549                      0                                    0
# 822                        0                                    0
#
#        Cities: La Rochelle (France)  Cities: Las Vegas (Nevada, USA)  \
# id
# 30549                             0                                0
# 822                               0                                0
#
#        Cities: Laval (France)  Cities: Le Havre (France)  \
# id
# 30549                       0                          0
# 822                         0                          0
#
#        Cities: Le Mans (France)  Cities: Legnica (Poland)  \
# id
# 30549                         0                         0
# 822                           0                         0
#
#        Cities: Leipzig (Saxony, Germany)  Cities: Lille (France)  \
# id
# 30549                                  0                       0
# 822                                    0                       0
#
#        Cities: Lisbon (Portugal)  Cities: Lodz (Poland)  \
# id
# 30549                          0                      0
# 822                            0                      0
#
#        Cities: London (England)  Cities: Lorient (France)  \
# id
# 30549                         0                         0
# 822                           0                         0
#
#        Cities: Los Angeles (California, USA)  \
# id
# 30549                                      0
# 822                                        0
#
#        Cities: Lovosice (Czech Republic)  Cities: Lucca (Italy)  \
# id
# 30549                                  0                      0
# 822                                    0                      0
#
#        Cities: Luxor (Egypt)  Cities: Lviv (Ukraine)  \
# id
# 30549                      0                       0
# 822                        0                       0
#
#        Cities: Lübeck (Germany)  Cities: Lüshunkou (China)  \
# id
# 30549                         0                          0
# 822                           0                          0
#
#        Cities: Maastricht (Netherlands)  Cities: Madrid (Spain)  \
# id
# 30549                                 0                       0
# 822                                   0                       0
#
#        Cities: Malmö (Sweden)  Cities: Manchester (England)  \
# id
# 30549                       0                             0
# 822                         0                             0
#
#        Cities: Manila (Philippines)  Cities: Maracaibo (Venezuela)  \
# id
# 30549                             0                              0
# 822                               0                              0
#
#        Cities: Marengo (Italy)  Cities: Marignano (Italy)  \
# id
# 30549                        0                          0
# 822                          0                          0
#
#        Cities: Marrakech (Morocco)  Cities: Marseille (France)  \
# id
# 30549                            0                           0
# 822                              0                           0
#
#        Cities: Mecca (Saudi Arabia)  Cities: Medellín (Spain)  \
# id
# 30549                             0                         0
# 822                               0                         0
#
#        Cities: Metz (France)  Cities: Miami (Florida, USA)  \
# ...
# 822                  0                 0               0               0
#
#        Toys: Barbie  Toys: Bionicle  Toys: Bratz  Toys: Filly  \
# id
# 30549             0               0            0            0
# 822               0               0            0            0
#
#        Toys: Fisher Price Little People  Toys: G.I. Joe  Toys: Gormiti  \
# id
# 30549                                 0               0              0
# 822                                   0               0              0
#
#        Toys: LEGO  Toys: Lalaloopsy  Toys: Littlest Pet Shop  \
# id
# 30549           0                 0                        0
# 822             0                 0                        0
#
#        Toys: Masters of the Universe  Toys: My Little Pony  Toys: Playmobil  \
# id
# 30549                              0                     0                0
# 822                                0                     0                0
#
#        Toys: Polly Pocket  Toys: Shopkins  Toys: Transformers  \
# id
# 30549                   0               0                   0
# 822                     0               0                   0
#
#        Traditional Card Games: Bridge  Traditional Card Games: Cribbage  \
# id
# 30549                               0                                 0
# 822                                 0                                 0
#
#        Traditional Card Games: Eights  Traditional Card Games: Go Fish  \
# id
# 30549                               0                                0
# 822                                 0                                0
#
#        Traditional Card Games: Golf  Traditional Card Games: Hearts  \
# id
# 30549                             0                               0
# 822                               0                               0
#
#        Traditional Card Games: Jass  Traditional Card Games: Kemps  \
# id
# 30549                             0                              0
# 822                               0                              0
#
#        Traditional Card Games: Old Maid  Traditional Card Games: Palace  \
# id
# 30549                                 0                               0
# 822                                   0                               0
#
#        Traditional Card Games: Poker  Traditional Card Games: Rummy  \
# id
# 30549                              0                              0
# 822                                0                              0
#
#        Traditional Card Games: Snap  Traditional Card Games: Spite and Malice  \
# id
# 30549                             0                                         0
# 822                               0                                         0
#
#        Traditional Card Games: War  Traditional Dice Games: Craps  \
# id
# 30549                            0                              0
# 822                              0                              0
#
#        Traditional Dice Games: Yacht  Traditional Games: 20 Questions  \
# id
# 30549                              0                                0
# 822                                0                                0
#
#        Traditional Games: Alquerque  \
# id
# 30549                             0
# 822                               0
#
#        Traditional Games: Alquerque / Fanorona (Indian War Games)  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Traditional Games: Backgammon  Traditional Games: Bezique/Pinochle  \
# id
# 30549                              0                                    0
# 822                                0                                    0
#
#        Traditional Games: Bingo  Traditional Games: Carrom  \
# id
# 30549                         0                          0
# 822                           0                          0
#
#        Traditional Games: Categories / Guggenheim  \
# id
# 30549                                           0
# 822                                             0
#
#        Traditional Games: Charades  Traditional Games: Checkers / Draughts  \
# id
# 30549                            0                                       0
# 822                              0                                       0
#
#        Traditional Games: Chess  Traditional Games: Crokinole  \
# id
# 30549                         0                             0
# 822                           0                             0
#
#        Traditional Games: Dice 10,000 games  Traditional Games: Dictionary  \
# id
# 30549                                     0                              0
# 822                                       0                              0
#
#        Traditional Games: Dominoes  Traditional Games: Dots and Boxes  \
# id
# 30549                            0                                  0
# 822                              0                                  0
#
#        Traditional Games: Fox and Geese  Traditional Games: Game of Goose  \
# id
# 30549                                 0                                 0
# 822                                   0                                 0
#
#        Traditional Games: Go  Traditional Games: Goita  \
# id
# 30549                      0                         0
# 822                        0                         0
#
#        Traditional Games: Halma  Traditional Games: Hanafuda  \
# id
# 30549                         0                            0
# 822                           0                            0
#
#        Traditional Games: Knucklebones / Jacks  Traditional Games: Mahjong  \
# id
# 30549                                        0                           0
# 822                                          0                           0
#
#        Traditional Games: Mancala  Traditional Games: Morris  \
# id
# 30549                           0                          0
# 822                             0                          0
#
#        Traditional Games: Pachisi / Ludo  Traditional Games: Petteia  \
# id
# 30549                                  0                           0
# 822                                    0                           0
#
#        Traditional Games: Shogi  Traditional Games: Shut the Box  \
# id
# 30549                         0                                0
# 822                           0                                0
#
#        Traditional Games: Snakes and Ladders  Traditional Games: Spoons  \
# id
# 30549                                      0                          0
# 822                                        0                          0
#
#        Traditional Games: Sudoku  Traditional Games: Tafl  \
# id
# 30549                          0                        0
# 822                            0                        0
#
#        Traditional Games: Tiddlywinks  Traditional Games: Yut Nori  \
# id
# 30549                               0                            0
# 822                                 0                            0
#
#        Versions & Editions: Adult Versions of Family-Friendly Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Big Box Versions of Individual Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Board Game Versions of Role-Playing Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Card Versions of Non-Card Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Dice Versions of Non-Dice Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Disney Theme Park Editions  \
# id
# 30549                                                0
# 822                                                  0
#
#        Versions & Editions: Electronic Versions of Non-Electronic Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Junior Versions of Grown-Up Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Legacy Versions of Non-Legacy Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Roll- or Flip-and-Write Versions of Non-Writing Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Travel Versions of Non-Travel Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Two-Player Versions of More-Player Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Video Game Theme: Angry Birds  Video Game Theme: Carmen Sandiego  \
# id
# 30549                              0                                  0
# 822                                0                                  0
#
#        Video Game Theme: Doom  Video Game Theme: Dragon Quest  \
# id
# 30549                       0                               0
# 822                         0                               0
#
#        Video Game Theme: Final Fantasy  Video Game Theme: Fruit Ninja  \
# id
# 30549                                0                              0
# 822                                  0                              0
#
#        Video Game Theme: Honfoglaló  Video Game Theme: Kingdom Hearts  \
# id
# 30549                             0                                 0
# 822                               0                                 0
#
#        Video Game Theme: Minecraft  Video Game Theme: Nintendo  \
# id
# 30549                            0                           0
# 822                              0                           0
#
#        Video Game Theme: Pac-Man  Video Game Theme: Pokémon  \
# id
# 30549                          0                          0
# 822                            0                          0
#
#        Video Game Theme: Project Shrine Maiden  \
# id
# 30549                                        0
# 822                                          0
#
#        Video Game Theme: Resident Evil  Video Game Theme: SEGA  \
# id
# 30549                                0                       0
# 822                                  0                       0
#
#        Video Game Theme: Sonic the Hedgehog  \
# id
# 30549                                     0
# 822                                       0
#
#        Video Game Theme: Super Mario Bros.  Video Game Theme: Tetris  \
# id
# 30549                                    0                         0
# 822                                      0                         0
#
#        Video Game Theme: The Oregon Trail  Webcomics: Dork Tower  \
# id
# 30549                                   0                      0
# 822                                     0                      0
#
#        Webcomics: Penny Arcade  Word Games: First Letter Given  \
# id
# 30549                        0                               0
# 822                          0                               0
#
#        Word Games: Guess the Word  Word Games: Spelling / Letters
# id
# 30549                           0                               0
# 822                             0                               0

# %%
df_family = complete_ohe(df_content, df_ohe=df_family, unpacked_column = "boardgamefamily")
pd.options.display.max_columns = 100
df_family.head(2)
# Out:
#        Ancient: Babylon  Ancient: Carthage  Ancient: Corinth  Ancient: Egypt  \
# id
# 30549                 0                  0                 0               0
# 822                   0                  0                 0               0
#
#        Ancient: Greece  Ancient: Indus Valley  Ancient: Jericho  \
# id
# 30549                0                      0                 0
# 822                  0                      0                 0
#
#        Ancient: Magna Graecia  Ancient: Mesopotamia  Ancient: Pompeii  \
# id
# 30549                       0                     0                 0
# 822                         0                     0                 0
#
#        Ancient: Rome  Ancient: Sparta  Animals: Alligators / Crocodiles  \
# id
# 30549              0                0                                 0
# 822                0                0                                 0
#
#        Animals: Ants  Animals: Apes / Monkeys  Animals: Badgers  \
# id
# 30549              0                        0                 0
# 822                0                        0                 0
#
#        Animals: Bats  Animals: Bears  Animals: Beavers  Animals: Bees  \
# id
# 30549              0               0                 0              0
# 822                0               0                 0              0
#
#        Animals: Birds  Animals: Butterflies  Animals: Camels  Animals: Cats  \
# id
# 30549               0                     0                0              0
# 822                 0                     0                0              0
#
#        Animals: Cattle / Cows  Animals: Chameleons  Animals: Chickens  \
# id
# 30549                       0                    0                  0
# 822                         0                    0                  0
#
#        Animals: Cockroaches  Animals: Coral / Jellyfish / Anemones  \
# id
# 30549                     0                                      0
# 822                       0                                      0
#
#        Animals: Coyotes  Animals: Crabs  Animals: Crows / Ravens / Magpies  \
# id
# 30549                 0               0                                  0
# 822                   0               0                                  0
#
#        Animals: Deer / Antelope  Animals: Dinosaurs  Animals: Dogs  \
# id
# 30549                         0                   0              0
# 822                           0                   0              0
#
#        Animals: Dolphins  Animals: Donkeys  Animals: Ducks  Animals: Eagles  \
# id
# 30549                  0                 0               0                0
# 822                    0                 0               0                0
#
#        Animals: Elephants  Animals: Emus  Animals: Fish / Fishes  \
# id
# 30549                   0              0                       0
# 822                     0              0                       0
#
#        Animals: Fleas  Animals: Flies  Animals: Foxes  Animals: Frogs / Toads  \
# id
# 30549               0               0               0                       0
# 822                 0               0               0                       0
#
#        Animals: Geese  Animals: Giraffes  Animals: Goats  Animals: Gophers  \
# id
# 30549               0                  0               0                 0
# 822                 0                  0               0                 0
#
#        ...  Traditional Games: Knucklebones / Jacks  \
# id     ...
# 30549  ...                                        0
# 822    ...                                        0
#
#        Traditional Games: Mahjong  Traditional Games: Mancala  \
# id
# 30549                           0                           0
# 822                             0                           0
#
#        Traditional Games: Morris  Traditional Games: Pachisi / Ludo  \
# id
# 30549                          0                                  0
# 822                            0                                  0
#
#        Traditional Games: Petteia  Traditional Games: Shogi  \
# id
# 30549                           0                         0
# 822                             0                         0
#
#        Traditional Games: Shut the Box  Traditional Games: Snakes and Ladders  \
# id
# 30549                                0                                      0
# 822                                  0                                      0
#
#        Traditional Games: Spoons  Traditional Games: Sudoku  \
# id
# 30549                          0                          0
# 822                            0                          0
#
#        Traditional Games: Tafl  Traditional Games: Tiddlywinks  \
# id
# 30549                        0                               0
# 822                          0                               0
#
#        Traditional Games: Yut Nori  \
# id
# 30549                            0
# 822                              0
#
#        Versions & Editions: Adult Versions of Family-Friendly Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Big Box Versions of Individual Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Board Game Versions of Role-Playing Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Card Versions of Non-Card Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Dice Versions of Non-Dice Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Disney Theme Park Editions  \
# id
# 30549                                                0
# 822                                                  0
#
#        Versions & Editions: Electronic Versions of Non-Electronic Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Junior Versions of Grown-Up Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Legacy Versions of Non-Legacy Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Roll- or Flip-and-Write Versions of Non-Writing Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Travel Versions of Non-Travel Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Versions & Editions: Two-Player Versions of More-Player Games  \
# id
# 30549                                                  0
# 822                                                    0
#
#        Video Game Theme: Angry Birds  Video Game Theme: Carmen Sandiego  \
# id
# 30549                              0                                  0
# 822                                0                                  0
#
#        Video Game Theme: Doom  Video Game Theme: Dragon Quest  \
# id
# 30549                       0                               0
# 822                         0                               0
#
#        Video Game Theme: Final Fantasy  Video Game Theme: Fruit Ninja  \
# id
# 30549                                0                              0
# 822                                  0                              0
#
#        Video Game Theme: Honfoglaló  Video Game Theme: Kingdom Hearts  \
# id
# 30549                             0                                 0
# 822                               0                                 0
#
#        Video Game Theme: Minecraft  Video Game Theme: Nintendo  \
# id
# 30549                            0                           0
# 822                              0                           0
#
#        Video Game Theme: Pac-Man  Video Game Theme: Pokémon  \
# id
# 30549                          0                          0
# 822                            0                          0
#
#        Video Game Theme: Project Shrine Maiden  \
# id
# 30549                                        0
# 822                                          0
#
#        Video Game Theme: Resident Evil  Video Game Theme: SEGA  \
# id
# 30549                                0                       0
# 822                                  0                       0
#
#        Video Game Theme: Sonic the Hedgehog  \
# id
# 30549                                     0
# 822                                       0
#
#        Video Game Theme: Super Mario Bros.  Video Game Theme: Tetris  \
# id
# 30549                                    0                         0
# 822                                      0                         0
#
#        Video Game Theme: The Oregon Trail  Webcomics: Dork Tower  \
# id
# 30549                                   0                      0
# 822                                     0                      0
#
#        Webcomics: Penny Arcade  Word Games: First Letter Given  \
# id
# 30549                        0                               0
# 822                          0                               0
#
#        Word Games: Guess the Word  Word Games: Spelling / Letters
# id
# 30549                           0                               0
# 822                             0                               0
#
# [2 rows x 2643 columns]

# %% [markdown]
# Let's check the shape of df_family

# %%
df_family.shape
# Out:
# (21348, 2643)

# %% [markdown]
# We can drop columns which have values in only one game.

# %%
(df_family.sum()==1).sum()
# Out:
# 448

# %%
columns_to_drop = df_family.columns[df_family.sum()==1]
print(columns_to_drop.tolist())
# Out:
# ['Ancient: Magna Graecia', 'Animals: Sloths', 'Authors: Astrid Lindgren', 'Authors: Ellery Queen', 'Authors: Karl May', 'Authors: Michael Moorcock', 'Books: Alfons Åberg', 'Books: Angelina Ballerina', 'Books: Charlie and Lola', 'Books: Charlie and the Chocolate Factory', 'Books: Der Dativ ist dem Genitiv sein Tod', 'Books: Der Kleine König', 'Books: Felix', 'Books: Goosebumps', 'Books: Hopalong Cassidy', 'Books: Inkworld', 'Books: Jim Button', 'Books: Le Petit Poucet', 'Books: Lilly the Witch', 'Books: Little Bear', 'Books: Little Raven Socks', 'Books: My Secret Unicorn', 'Books: The Berenstain Bears', "Brands: Campbell's", 'Brands: Harley-Davidson', 'Brands: John Deere', "Brands: McDonald's", 'Category: Drinking Games', 'Celebrities: Don Adams', 'Celebrities: Lucille Ball', 'Celebrities: The Wiggles', 'Characters:  The Addams Family', 'Characters: Bozo the Clown', 'Characters: Buck Rogers', 'Characters: Caillou', "Characters: Capt'n Sharky", "Characters: Käpt'n Blaubär", 'Characters: Lassie', 'Characters: Perry Rhodan', 'Characters: Pettersson und Findus', 'Characters: The Lone Ranger', 'Characters: The Three Stooges', 'Characters: Zorro', 'Cities: Abbeville (France)', 'Cities: Albuera (Spain)', 'Cities: Antwerp (Belgium)', 'Cities: Arcachon (France)', 'Cities: Augsburg (Bavaria, Germany)', 'Cities: Bailén (Spain)', 'Cities: Baltimore (Maryland, USA)', 'Cities: Bamberg (Bavaria, Germany)', 'Cities: Bangkok (Thailand)', 'Cities: Bergamo (Italy)', 'Cities: Bern (Switzerland)', 'Cities: Bilbao (Spain)', 'Cities: Bologna (Emilia-Romagna, Italy)', 'Cities: Bonn (Westphalia, Germany)', 'Cities: Bourges (France)', 'Cities: Bremerhaven (Germany)', 'Cities: Brisbane (Australia)', 'Cities: Bristol (England)', 'Cities: Buffalo (New York, USA)', 'Cities: Caen (France)', 'Cities: Canberra (Australia)', 'Cities: Cannes (France)', 'Cities: Casablanca (Morocco)', 'Cities: Changde (China)', 'Cities: Cherbourg-en-Cotentin (France)', 'Cities: Cincinnati (Ohio, USA)', 'Cities: Corunna (Spain)', 'Cities: Damascus (Syria)', 'Cities: Debrecen (Hungary)', 'Cities: Dieppe (France)', 'Cities: Dinant (Belgium)', 'Cities: Dodge City (Kansas, USA)', 'Cities: Dortmund (North Rhine-Westphalia, Germany)', 'Cities: Dublin (Ireland)', 'Cities: Estoril (Portugal)', 'Cities: Falaise (France)', 'Cities: Fallujah (Iraq)', 'Cities: Glasgow (Scotland)', 'Cities: Grenoble (France)', 'Cities: Grozny (Chechnya)', 'Cities: Győr (Hungary)', 'Cities: Hameln (Saxony, Germany)', 'Cities: Hannut (Belgium)', 'Cities: Hanover (Lower Saxony, Germany)', 'Cities: Helsinki (Finland)', 'Cities: Incheon (South Korea)', 'Cities: Khartoum (Sudan)', 'Cities: Königgrätz (Czech Republic)', 'Cities: La Rochelle (France)', 'Cities: Legnica (Poland)', 'Cities: Lodz (Poland)', 'Cities: Lorient (France)', 'Cities: Lübeck (Germany)', 'Cities: Maastricht (Netherlands)', 'Cities: Malmö (Sweden)', 'Cities: Maracaibo (Venezuela)', 'Cities: Marignano (Italy)', 'Cities: Marseille (France)', 'Cities: Mecca (Saudi Arabia)', 'Cities: Medellín (Spain)', 'Cities: Miami (Florida, USA)', 'Cities: Minden (Germany)', 'Cities: Monte Carlo (Monaco)', 'Cities: Mortain (France)', 'Cities: Murmansk (Russia)', 'Cities: Málaga (Spain)', 'Cities: Nagano (Japan)', 'Cities: Nancy (France)', 'Cities: Nantes (France)', 'Cities: Nashville (Tennessee, USA)', 'Cities: Novgorod (Russia)', 'Cities: Nîmes (France)', 'Cities: Oldenburg (Saxony, Germany)', 'Cities: Oxford (Oxfordshire, England)', 'Cities: Panama City (Panama)', 'Cities: Parma (Italy)', 'Cities: Portland (Oregon, USA)', 'Cities: Porto (Portugal)', 'Cities: Quimper (France)', 'Cities: Ravenna (Italy)', 'Cities: Regensburg (Bavaria, Germany)', 'Cities: Reims (France)', 'Cities: Reykjavík (Iceland)', 'Cities: Rhodes (Greece)', 'Cities: Riga (Latvia)', 'Cities: Saint Malo (France)', 'Cities: Saint-Lô (France)', 'Cities: Saint-Nazaire (France)', 'Cities: Sainte-Mère-Église (France)', 'Cities: Salamanca (Spain)', 'Cities: Salzburg (Austria)', 'Cities: Samara (Russia) ...

# %% [markdown]
# Actually these columns are very specific and belong to one game.<br>
# We could merge them as a group,but we already have such broad-term columns in df_category.<br>
# For example, df_category contain columns such as "Ancient","Book", "Dice" and "Video Game Theme".<br>
# Therefore we remove these columns.

# %%
df_family.drop(columns=columns_to_drop,inplace=True)
df_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21348 entries, 30549 to 165946
# Columns: 2195 entries, Ancient: Babylon to Word Games: Spelling / Letters
# dtypes: int8(2195)
# memory usage: 45.4 MB

# %% [markdown]
# ## 3.4 Save three ohe dataframes;df_category,df_mechanic, and df_family in dictionary **df_content_dict**

# %% [markdown]
# In the previous part we initialized dataframes with zeros, and then assigned ones to corresponding columns in the original column.<br>
# Due to the assignment of ones we could not use sparse datatype, but once we have completed assigning ones, we can convert dataframes
# to sparse datatype.

# %%
df_category = df_category.astype(pd.SparseDtype("bool"))

# %%
df_mechanic = df_mechanic.astype(pd.SparseDtype("bool"))
df_mechanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21348 entries, 30549 to 165946
# Columns: 182 entries, Acting to Zone of Control
# dtypes: Sparse[bool, False](182)
# memory usage: 987.5 KB

# %%
df_family = df_family.astype(pd.SparseDtype("bool"))
df_family.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21348 entries, 30549 to 165946
# Columns: 2195 entries, Ancient: Babylon to Word Games: Spelling / Letters
# dtypes: Sparse[bool, False](2195)
# memory usage: 871.4 KB

# %% [markdown]
# ## 3.4 A Final Adjustment: Assign Values to Not Ranked Values in Board_Game_Rank Column

# %% [markdown]
# * We will use game rankings in the case of equality in similarities(distances).
# * In such cases we will suggest the games with higher ranks first.
#
# * If we observe the *Board_Game_Rank* column we notive that there are few games not ranked.

# %%
sum(df_content["Board_Game_Rank"]=="Not Ranked")
# Out:
# 5

# %% [markdown]
#  We can replace them with a number greater than the number of games. Let's simply say a invalid rank; 100000.

# %%
df_content["Board_Game_Rank"]=df_content["Board_Game_Rank"].replace({"Not Ranked":"100000"})
df_content.head(2)
# Out:
#       Board_Game_Rank                              boardgamecategory  \
# id
# 30549             106                                      [Medical]
# 822               191  [City Building, Medieval, Territory Building]
#
#                                        boardgamemechanic  \
# id
# 30549  [Action Points, Cooperative Game, Hand Managem...
# 822    [Area Majority / Influence, Map Addition, Tile...
#
#                                          boardgamefamily
# id
# 30549  [Components: Map (Global Scale), Components: M...
# 822    [Cities: Carcassonne (France), Components: Mee...

# %%
df_content["Board_Game_Rank"].dtype
# Out:
# dtype('O')

# %% [markdown]
# Since we have replaced "Not Ranked" with 100000, now we can convert the data type of this column from Object to integer.

# %%
df_content["Board_Game_Rank"]= df_content["Board_Game_Rank"].astype("uint32")

# %% [markdown]
# # 4- Save the dataframes in a dictionary.

# %% [markdown]
# Now we can save the dataframes below in a dictionary **df_content_dict** which has
# * **Board Game Rank**
# * **one-hot boardgamecategory**
# * **one-hot boardgamemechanic**
# * **one-hot boardgamefamily**
# columns

# %% [markdown]
# We save the dataframes seperately, because we will calculate distances for each of them seperately.

# %%
df_content_dict ={"rank":df_content[["Board_Game_Rank"]],"category":df_category,"mechanic":df_mechanic,"family":df_family}

# %%
import pickle
# Save for the deployment
with open('df_content_dict.pkl', 'wb') as file:
    pickle.dump(df_content_dict, file)
